# %%
import pandas as pd
import numpy as np

# %%
serie1 = pd.Series(["Paolo","Luca","Pietro","Matteo"])
print(serie1)

serie2 = pd.Series(
    [8, 7.5, 6, 10],
    index=["Matteo", "Luca", "Franco", "Mattia"]
)

print(serie2)
# Out:
# 0     Paolo
# 1      Luca
# 2    Pietro
# 3    Matteo
# dtype: str
# Matteo     8.0
# Luca       7.5
# Franco     6.0
# Mattia    10.0
# dtype: float64
